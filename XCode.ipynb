# %%
import torch
from torchvision import models
from torchprofile.utils.trace import trace
from torchprofile import profile_macs
import numpy as np
if __name__ == '__main__':
    for name, model in models.__dict__.items():
        if not name.islower() or name.startswith('__') or not callable(model):
            continue

        model = model().eval()
        if 'inception' not in name:
            inputs = torch.randn(1, 3, 224, 224)
        else:
            inputs = torch.randn(1, 3, 299, 299)

        macs = profile_macs(model, inputs)
        if 'resnet50' in name:
            graph = trace(model,inputs)
            print(graph)
            # with open('graph_resnet18.txt', 'w') as file:
            #     file.write(graph)
        print('{}: {:.4g} G'.format(name, macs / 1e9))
# Out:
# alexnet: 0.7142 G
# resnet18: 1.814 G
# resnet34: 3.664 G
# torchvision.models.resnet.ResNet (
# 	%input.1: float[1, 3, 224, 224],
# 	%1: float[64, 3, 7, 7],
# 	%2: float[64],
# 	%3: float[64],
# 	%4: float[64],
# 	%5: float[64],
# 	%7: float[64, 64, 1, 1],
# 	%8: float[64],
# 	%9: float[64],
# 	%10: float[64],
# 	%11: float[64],
# 	%13: float[64, 64, 3, 3],
# 	%14: float[64],
# 	%15: float[64],
# 	%16: float[64],
# 	%17: float[64],
# 	%19: float[256, 64, 1, 1],
# 	%20: float[256],
# 	%21: float[256],
# 	%22: float[256],
# 	%23: float[256],
# 	%25: float[256, 64, 1, 1],
# 	%26: float[256],
# 	%27: float[256],
# 	%28: float[256],
# 	%29: float[256],
# 	%31: float[64, 256, 1, 1],
# 	%32: float[64],
# 	%33: float[64],
# 	%34: float[64],
# 	%35: float[64],
# 	%37: float[64, 64, 3, 3],
# 	%38: float[64],
# 	%39: float[64],
# 	%40: float[64],
# 	%41: float[64],
# 	%43: float[256, 64, 1, 1],
# 	%44: float[256],
# 	%45: float[256],
# 	%46: float[256],
# 	%47: float[256],
# 	%49: float[64, 256, 1, 1],
# 	%50: float[64],
# 	%51: float[64],
# 	%52: float[64],
# 	%53: float[64],
# 	%55: float[64, 64, 3, 3],
# 	%56: float[64],
# 	%57: float[64],
# 	%58: float[64],
# 	%59: float[64],
# 	%61: float[256, 64, 1, 1],
# 	%62: float[256],
# 	%63: float[256],
# 	%64: float[256],
# 	%65: float[256],
# 	%67: float[128, 256, 1, 1],
# 	%68: float[128],
# 	%69: float[128],
# 	%70: float[128],
# 	%71: float[128],
# 	%73: float[128, 128, 3, 3],
# 	%74: float[128],
# 	%75: float[128],
# 	%76: float[128],
# 	%77: float[128],
# 	%79: float[512, 128, 1, 1],
# 	%80: float[512],
# 	%81: float[512],
# 	%82: float[512],
# 	%83: float[512],
# 	%85: float[512, 256, 1, 1],
# 	%86: float[512],
# 	%87: float[512],
# 	%88: float[512],
# 	%89: float[512],
# 	%91: float[128, 512, 1, 1],
# 	%92: float[128],
# 	%93: float[128],
# 	%94: float[128],
# 	%95: float[128],
# 	%97: float[128, 128, 3, 3],
# 	%98: float[128],
# 	%99: float[128],
# 	%100: float[128],
# 	%101: float[128],
# 	%103: float[512, 128, 1, 1],
# 	%104: float[512],
# 	%105: float[512],
# 	%106: float[512],
# 	%107: float[512],
# 	%109: float[128, 512, 1, 1],
# 	%110: float[128],
# 	%111: float[128],
# 	%112: float[128],
# 	%113: float[128],
# 	%115: float[128, 128, 3, 3],
# 	%116: float[128],
# 	%117: float[128],
# 	%118: float[128],
# 	%119: float[128],
# 	%121: float[512, 128, 1, 1],
# 	%122: float[512],
# 	%123: float[512],
# 	%124: float[512],
# 	%125: float[512],
# 	%127: float[128, 512, 1, 1],
# 	%128: float[128],
# 	%129: float[128],
# 	%130: float[128],
# 	%131: float[128],
# 	%133: float[128, 128, 3, 3],
# 	%134: float[128],
# 	%135: float[128],
# 	%136: float[128],
# 	%137: float[128],
# 	%139: float[512, 128, 1, 1],
# 	%140: float[512],
# 	%141: float[512],
# 	%142: float[512],
# 	%143: float[512],
# 	%145: float[256, 512, 1, 1],
# 	%146: float[256],
# 	%147: float[256],
# 	%148: float[256],
# 	%149: float[256],
# 	%151: float[256, 256, 3, 3],
# 	%152: float[256],
# 	%153: float[256],
# 	%154: float[256],
# 	%155: float[256],
# 	%157: float[1024, 256, 1, 1],
# 	%158: float[1024],
# 	%159: float[1024],
# 	%160: float[1024],
# 	%161: float[1024],
# 	%163: float[1024, 512, 1, 1],
# 	%164: float[1024],
# 	%165: float[1024],
# 	%166: float[1024],
# 	%167: float[1024],
# 	%169: float[256, 1024, 1, 1],
# 	%170: float[256],
# 	%171: float[256],
# 	%172: float[256],
# 	%173: float[256],
# 	%175: float[256, 256, 3, 3],
# 	%176: float[256],
# 	%177: float[256],
# 	%178: float[256],
# 	%179: float[256],
# 	%181: float[1024, 256, 1, 1],
# 	%182: float[1024],
# 	%183: float[1024],
# 	%184: float[1024],
# 	%185: float[1024],
# 	%187: float[256, 1024, 1, 1],
# 	%188: float[256],
# 	%189: float[256],
# 	%190: float[256],
# 	%191: float[256],
# 	%193: float[256, 256, 3, 3],
# 	%194: float[256],
# 	%195: float[256],
# 	%196: float[256],
# 	%197: float[256],
# 	%199: float[1024, 256, 1, 1],
# 	%200: float[1024],
# 	%201: float[1024],
# 	%202: float[1024],
# 	%203: float[1024],
# 	%205: float[256, 1024, 1, 1],
# 	%206: float[256],
# 	%207: float[256],
# 	%208: float[256],
# 	%209: float[256],
# 	%211: float[256, 256, 3, 3],
# 	%212: float[256],
# 	%213: float[256],
# 	%214: float[256],
# 	%215: float[256],
# 	%217: float[1024, 256, 1, 1],
# 	%218: float[1024],
# 	%219: float[1024],
# 	%220: float[1024],
# 	%221: float[1024],
# 	%223: float[256, 1024, 1, 1],
# 	%224: float[256],
# 	%225: float[256],
# 	%226: float[256],
# 	%227: float[256],
# 	%229: float[256, 256, 3, 3],
# 	%230: float[256],
# 	%231: float[256],
# 	%232: float[256],
# 	%233: float[256],
# 	%235: float[1024, 256, 1, 1],
# 	%236: float[1024],
# 	%237: float[1024],
# 	%238: float[1024],
# 	%239: float[1024],
# 	%241: float[256, 1024, 1, 1],
# 	%242: float[256],
# 	%243: float[256],
# 	%244: float[256],
# 	%245: float[256],
# 	%247: float[256, 256, 3, 3],
# 	%248: float[256],
# 	%249: float[256],
# 	%250: float[256],
# 	%251: float[256],
# 	%253: float[1024, 256, 1, 1],
# 	%254: float[1024],
# 	%255: float[1024],
# 	%256: float[1024],
# 	%257: float[1024],
# 	%259: float[512, 1024, 1, 1],
# 	%260: float[512],
# 	%261: float[512],
# 	%262: float[512],
# 	%263: float[512],
# 	%265: float[512, 512, 3, 3],
# 	%266: float[512],
# 	%267: float[512],
# 	%268: float[512],
# 	%269: float[512],
# 	%271: float[2048, 512, 1, 1],
# 	%272: float[2048],
# 	%273: float[2048],
# 	%274: float[2048],
# 	%275: float[2048],
# 	%277: float[2048, 1024, 1, 1],
# 	%278: float[2048],
# 	%279: float[2048],
# 	%280: float[2048],
# 	%281: float[2048],
# 	%283: float[512, 2048, 1, 1],
# 	%284: float[512],
# 	%285: float[512],
# 	%286: float[512],
# 	%287: float[512],
# 	%289: float[512, 512, 3, 3],
# 	%290: float[512],
# 	%291: float[512],
# 	%292: float[512],
# 	%293: float[512],
# 	%295: float[2048, 512, 1, 1],
# 	%296: float[2048],
# 	%297: float[2048],
# 	%298: float[2048],
# 	%299: float[2048],
# 	%301: float[512, 2048, 1, 1],
# 	%302: float[512],
# 	%303: float[512],
# 	%304: float[512],
# 	%305: float[512],
# 	%307: float[512, 512, 3, 3],
# 	%308: float[512],
# 	%309: float[512],
# 	%310: float[512],
# 	%311: float[512],
# 	%313: float[2048, 512, 1, 1],
# 	%314: float[2048],
# 	%315: float[2048],
# 	%316: float[2048],
# 	%317: float[2048],
# 	%319: float[1000, 2048],
# 	%320: float[1000]
# ):
# 	%963: none = prim::constant()
# 	%964: int = prim::constant[value = 2]()
# 	%965: int = prim::constant[value = 2]()
# 	%966: list[int] = prim::listconstruct(%964: int, %965: int)
# 	%967: int = prim::constant[value = 3]()
# 	%968: int = prim::constant[value = 3]()
# 	%969: list[int] = prim::listconstruct(%967: int, %968: int)
# 	%970: int = prim::constant[value = 1]()
# 	%971: int = prim::constant[value = 1]()
# 	%972: list[int] = prim::listconstruct(%970: int, %971: int)
# 	%973: bool = prim::constant[value = 0]()
# 	%974: int = prim::constant[value = 0]()
# 	%975: int = prim::constant[value = 0]()
# 	%976: list[int] = prim::listconstruct(%974: int, %975: int)
# 	%977: int = prim::constant[value = 1]()
# 	%978: bool = prim::constant[value = 0]()
# 	%979: bool = prim::constant[value = 0]()
# 	%980: bool = prim::constant[value = 1]()
# 	%input.2: float[1, 64, 112, 112] = aten::_convolution(%input.1: float[1, 3, 224, 224], %1: float[64, 3, 7, 7], %963: none, %966: list[int], %969: list[int], %972: list[int], %973: bool, %976: list[int], %977: int, %978: bool, %979: bool, %980: bool)
# 	%982: bool = prim::constant[value = 0]()
# 	%983: float = prim::constant[value = 0.1]()
# 	%984: float = prim::constant[value = 1e-05]()
# 	%985: bool = prim::constant[value = 1]()
# 	%input.3: float[1, 64, 112, 112] = aten::batch_norm(%input.2: float[1, 64, 112, 112], %2: float[64], %3: float[64], %4: float[64], %5: float[64], %982: bool, %983: float, %984: float, %985: bool)
# 	%987: float[1, 64, 112, 112] = aten::relu_(%input.3: float[1, 64, 112, 112])
# 	%988: int = prim::constant[value = 3]()
# 	%989: int = prim::constant[value = 3]()
# 	%990: list[int] = prim::listconstruct(%988: int, %989: int)
# 	%991: int = prim::constant[value = 2]()
# 	%992: int = prim::constant[value = 2]()
# 	%993: list[int] = prim::listconstruct(%991: int, %992: int)
# 	%994: int = prim::constant[value = 1]()
# 	%995: int = prim::constant[value = 1]()
# 	%996: list[int] = prim::listconstruct(%994: int, %995: int)
# 	%997: int = prim::constant[value = 1]()
# 	%998: int = prim::constant[value = 1]()
# 	%999: list[int] = prim::listconstruct(%997: int, %998: int)
# 	%1000: bool = prim::constant[value = 0]()
# 	%input.4: float[1, 64, 56, 56] = aten::max_pool2d(%987: float[1, 64, 112, 112], %990: list[int], %993: list[int], %996: list[int], %999: list[int], %1000: bool)
# 	%1002: none = prim::constant()
# 	%1003: int = prim::constant[value = 1]()
# 	%1004: int = prim::constant[value = 1]()
# 	%1005: list[int] = prim::listconstruct(%1003: int, %1004: int)
# 	%1006: int = prim::constant[value = 0]()
# 	%1007: int = prim::constant[value = 0]()
# 	%1008: list[int] = prim::listconstruct(%1006: int, %1007: int)
# 	%1009: int = prim::constant[value = 1]()
# 	%1010: int = prim::constant[value = 1]()
# 	%1011: list[int] = prim::listconstruct(%1009: int, %1010: int)
# 	%1012: bool = prim::constant[value = 0]()
# 	%1013: int = prim::constant[value = 0]()
# 	%1014: int = prim::constant[value = 0]()
# 	%1015: list[int] = prim::listconstruct(%1013: int, %1014: int)
# 	%1016: int = prim::constant[value = 1]()
# 	%1017: bool = prim::constant[value = 0]()
# 	%1018: bool = prim::constant[value = 0]()
# 	%1019: bool = prim::constant[value = 1]()
# 	%input.5: float[1, 64, 56, 56] = aten::_convolution(%input.4: float[1, 64, 56, 56], %7: float[64, 64, 1, 1], %1002: none, %1005: list[int], %1008: list[int], %1011: list[int], %1012: bool, %1015: list[int], %1016: int, %1017: bool, %1018: bool, %1019: bool)
# 	%1021: bool = prim::constant[value = 0]()
# 	%1022: float = prim::constant[value = 0.1]()
# 	%1023: float = prim::constant[value = 1e-05]()
# 	%1024: bool = prim::constant[value = 1]()
# 	%input.6: float[1, 64, 56, 56] = aten::batch_norm(%input.5: float[1, 64, 56, 56], %8: float[64], %9: float[64], %10: float[64], %11: float[64], %1021: bool, %1022: float, %1023: float, %1024: bool)
# 	%input.7: float[1, 64, 56, 56] = aten::relu_(%input.6: float[1, 64, 56, 56])
# 	%1027: none = prim::constant()
# 	%1028: int = prim::constant[value = 1]()
# 	%1029: int = prim::constant[value = 1]()
# 	%1030: list[int] = prim::listconstruct(%1028: int, %1029: int)
# 	%1031: int = prim::constant[value = 1]()
# 	%1032: int = prim::constant[value = 1]()
# 	%1033: list[int] = prim::listconstruct(%1031: int, %1032: int)
# 	%1034: int = prim::constant[value = 1]()
# 	%1035: int = prim::constant[value = 1]()
# 	%1036: list[int] = prim::listconstruct(%1034: int, %1035: int)
# 	%1037: bool = prim::constant[value = 0]()
# 	%1038: int = prim::constant[value = 0]()
# 	%1039: int = prim::constant[value = 0]()
# 	%1040: list[int] = prim::listconstruct(%1038: int, %1039: int)
# 	%1041: int = prim::constant[value = 1]()
# 	%1042: bool = prim::constant[value = 0]()
# 	%1043: bool = prim::constant[value = 0]()
# 	%1044: bool = prim::constant[value = 1]()
# 	%input.8: float[1, 64, 56, 56] = aten::_convolution(%input.7: float[1, 64, 56, 56], %13: float[64, 64, 3, 3], %1027: none, %1030: list[int], %1033: list[int], %1036: list[int], %1037: bool, %1040: list[int], %1041: int, %1042: bool, %1043: bool, %1044: bool)
# 	%1046: bool = prim::constant[value = 0]()
# 	%1047: float = prim::constant[value = 0.1]()
# 	%1048: float = prim::constant[value = 1e-05]()
# 	%1049: bool = prim::constant[value = 1]()
# 	%input.9: float[1, 64, 56, 56] = aten::batch_norm(%input.8: float[1, 64, 56, 56], %14: float[64], %15: float[64], %16: float[64], %17: float[64], %1046: bool, %1047: float, %1048: float, %1049: bool)
# 	%input.10: float[1, 64, 56, 56] = aten::relu_(%input.9: float[1, 64, 56, 56])
# 	%1052: none = prim::constant()
# 	%1053: int = prim::constant[value = 1]()
# 	%1054: int = prim::constant[value = 1]()
# 	%1055: list[int] = prim::listconstruct(%1053: int, %1054: int)
# 	%1056: int = prim::constant[value = 0]()
# 	%1057: int = prim::constant[value = 0]()
# 	%1058: list[int] = prim::listconstruct(%1056: int, %1057: int)
# 	%1059: int = prim::constant[value = 1]()
# 	%1060: int = prim::constant[value = 1]()
# 	%1061: list[int] = prim::listconstruct(%1059: int, %1060: int)
# 	%1062: bool = prim::constant[value = 0]()
# 	%1063: int = prim::constant[value = 0]()
# 	%1064: int = prim::constant[value = 0]()
# 	%1065: list[int] = prim::listconstruct(%1063: int, %1064: int)
# 	%1066: int = prim::constant[value = 1]()
# 	%1067: bool = prim::constant[value = 0]()
# 	%1068: bool = prim::constant[value = 0]()
# 	%1069: bool = prim::constant[value = 1]()
# 	%input.11: float[1, 256, 56, 56] = aten::_convolution(%input.10: float[1, 64, 56, 56], %19: float[256, 64, 1, 1], %1052: none, %1055: list[int], %1058: list[int], %1061: list[int], %1062: bool, %1065: list[int], %1066: int, %1067: bool, %1068: bool, %1069: bool)
# 	%1071: bool = prim::constant[value = 0]()
# 	%1072: float = prim::constant[value = 0.1]()
# 	%1073: float = prim::constant[value = 1e-05]()
# 	%1074: bool = prim::constant[value = 1]()
# 	%1075: float[1, 256, 56, 56] = aten::batch_norm(%input.11: float[1, 256, 56, 56], %20: float[256], %21: float[256], %22: float[256], %23: float[256], %1071: bool, %1072: float, %1073: float, %1074: bool)
# 	%1076: none = prim::constant()
# 	%1077: int = prim::constant[value = 1]()
# 	%1078: int = prim::constant[value = 1]()
# 	%1079: list[int] = prim::listconstruct(%1077: int, %1078: int)
# 	%1080: int = prim::constant[value = 0]()
# 	%1081: int = prim::constant[value = 0]()
# 	%1082: list[int] = prim::listconstruct(%1080: int, %1081: int)
# 	%1083: int = prim::constant[value = 1]()
# 	%1084: int = prim::constant[value = 1]()
# 	%1085: list[int] = prim::listconstruct(%1083: int, %1084: int)
# 	%1086: bool = prim::constant[value = 0]()
# 	%1087: int = prim::constant[value = 0]()
# 	%1088: int = prim::constant[value = 0]()
# 	%1089: list[int] = prim::listconstruct(%1087: int, %1088: int)
# 	%1090: int = prim::constant[value = 1]()
# 	%1091: bool = prim::constant[value = 0]()
# 	%1092: bool = prim::constant[value = 0]()
# 	%1093: bool = prim::constant[value = 1]()
# 	%input.12: float[1, 256, 56, 56] = aten::_convolution(%input.4: float[1, 64, 56, 56], %25: float[256, 64, 1, 1], %1076: none, %1079: list[int], %1082: list[int], %1085: list[int], %1086: bool, %1089: list[int], %1090: int, %1091: bool, %1092: bool, %1093: bool)
# 	%1095: bool = prim::constant[value = 0]()
# 	%1096: float = prim::constant[value = 0.1]()
# 	%1097: float = prim::constant[value = 1e-05]()
# 	%1098: bool = prim::constant[value = 1]()
# 	%1099: float[1, 256, 56, 56] = aten::batch_norm(%input.12: float[1, 256, 56, 56], %26: float[256], %27: float[256], %28: float[256], %29: float[256], %1095: bool, %1096: float, %1097: float, %1098: bool)
# 	%1100: int = prim::constant[value = 1]()
# 	%input.13: float[1, 256, 56, 56] = aten::add_(%1075: float[1, 256, 56, 56], %1099: float[1, 256, 56, 56], %1100: int)
# 	%input.14: float[1, 256, 56, 56] = aten::relu_(%input.13: float[1, 256, 56, 56])
# 	%1103: none = prim::constant()
# 	%1104: int = prim::constant[value = 1]()
# 	%1105: int = prim::constant[value = 1]()
# 	%1106: list[int] = prim::listconstruct(%1104: int, %1105: int)
# 	%1107: int = prim::constant[value = 0]()
# 	%1108: int = prim::constant[value = 0]()
# 	%1109: list[int] = prim::listconstruct(%1107: int, %1108: int)
# 	%1110: int = prim::constant[value = 1]()
# 	%1111: int = prim::constant[value = 1]()
# 	%1112: list[int] = prim::listconstruct(%1110: int, %1111: int)
# 	%1113: bool = prim::constant[value = 0]()
# 	%1114: int = prim::constant[value = 0]()
# 	%1115: int = prim::constant[value = 0]()
# 	%1116: list[int] = prim::listconstruct(%1114: int, %1115: int)
# 	%1117: int = prim::constant[value = 1]()
# 	%1118: bool = prim::constant[value = 0]()
# 	%1119: bool = prim::constant[value = 0]()
# 	%1120: bool = prim::constant[value = 1]()
# 	%input.15: float[1, 64, 56, 56] = aten::_convolution(%input.14: float[1, 256, 56, 56], %31: float[64, 256, 1, 1], %1103: none, %1106: list[int], %1109: list[int], %1112: list[int], %1113: bool, %1116: list[int], %1117: int, %1118: bool, %1119: bool, %1120: bool)
# 	%1122: bool = prim::constant[value = 0]()
# 	%1123: float = prim::constant[value = 0.1]()
# 	%1124: float = prim::constant[value = 1e-05]()
# 	%1125: bool = prim::constant[value = 1]()
# 	%input.16: float[1, 64, 56, 56] = aten::batch_norm(%input.15: float[1, 64, 56, 56], %32: float[64], %33: float[64], %34: float[64], %35: float[64], %1122: bool, %1123: float, %1124: float, %1125: bool)
# 	%input.17: float[1, 64, 56, 56] = aten::relu_(%input.16: float[1, 64, 56, 56])
# 	%1128: none = prim::constant()
# 	%1129: int = prim::constant[value = 1]()
# 	%1130: int = prim::constant[value = 1]()
# 	%1131: list[int] = prim::listconstruct(%1129: int, %1130: int)
# 	%1132: int = prim::constant[value = 1]()
# 	%1133: int = prim::constant[value = 1]()
# 	%1134: list[int] = prim::listconstruct(%1132: int, %1133: int)
# 	%1135: int = prim::constant[value = 1]()
# 	%1136: int = prim::constant[value = 1]()
# 	%1137: list[int] = prim::listconstruct(%1135: int, %1136: int)
# 	%1138: bool = prim::constant[value = 0]()
# 	%1139: int = prim::constant[value = 0]()
# 	%1140: int = prim::constant[value = 0]()
# 	%1141: list[int] = prim::listconstruct(%1139: int, %1140: int)
# 	%1142: int = prim::constant[value = 1]()
# 	%1143: bool = prim::constant[value = 0]()
# 	%1144: bool = prim::constant[value = 0]()
# 	%1145: bool = prim::constant[value = 1]()
# 	%input.18: float[1, 64, 56, 56] = aten::_convolution(%input.17: float[1, 64, 56, 56], %37: float[64, 64, 3, 3], %1128: none, %1131: list[int], %1134: list[int], %1137: list[int], %1138: bool, %1141: list[int], %1142: int, %1143: bool, %1144: bool, %1145: bool)
# 	%1147: bool = prim::constant[value = 0]()
# 	%1148: float = prim::constant[value = 0.1]()
# 	%1149: float = prim::constant[value = 1e-05]()
# 	%1150: bool = prim::constant[value = 1]()
# 	%input.19: float[1, 64, 56, 56] = aten::batch_norm(%input.18: float[1, 64, 56, 56], %38: float[64], %39: float[64], %40: float[64], %41: float[64], %1147: bool, %1148: float, %1149: float, %1150: bool)
# 	%input.20: float[1, 64, 56, 56] = aten::relu_(%input.19: float[1, 64, 56, 56])
# 	%1153: none = prim::constant()
# 	%1154: int = prim::constant[value = 1]()
# 	%1155: int = prim::constant[value = 1]()
# 	%1156: list[int] = prim::listconstruct(%1154: int, %1155: int)
# 	%1157: int = prim::constant[value = 0]()
# 	%1158: int = prim::constant[value = 0]()
# 	%1159: list[int] = prim::listconstruct(%1157: int, %1158: int)
# 	%1160: int = prim::constant[value = 1]()
# 	%1161: int = prim::constant[value = 1]()
# 	%1162: list[int] = prim::listconstruct(%1160: int, %1161: int)
# 	%1163: bool = prim::constant[value = 0]()
# 	%1164: int = prim::constant[value = 0]()
# 	%1165: int = prim::constant[value = 0]()
# 	%1166: list[int] = prim::listconstruct(%1164: int, %1165: int)
# 	%1167: int = prim::constant[value = 1]()
# 	%1168: bool = prim::constant[value = 0]()
# 	%1169: bool = prim::constant[value = 0]()
# 	%1170: bool = prim::constant[value = 1]()
# 	%input.21: float[1, 256, 56, 56] = aten::_convolution(%input.20: float[1, 64, 56, 56], %43: float[256, 64, 1, 1], %1153: none, %1156: list[int], %1159: list[int], %1162: list[int], %1163: bool, %1166: list[int], %1167: int, %1168: bool, %1169: bool, %1170: bool)
# 	%1172: bool = prim::constant[value = 0]()
# 	%1173: float = prim::constant[value = 0.1]()
# 	%1174: float = prim::constant[value = 1e-05]()
# 	%1175: bool = prim::constant[value = 1]()
# 	%1176: float[1, 256, 56, 56] = aten::batch_norm(%input.21: float[1, 256, 56, 56], %44: float[256], %45: float[256], %46: float[256], %47: float[256], %1172: bool, %1173: float, %1174: float, %1175: bool)
# 	%1177: int = prim::constant[value = 1]()
# 	%input.22: float[1, 256, 56, 56] = aten::add_(%1176: float[1, 256, 56, 56], %input.14: float[1, 256, 56, 56], %1177: int)
# 	%input.23: float[1, 256, 56, 56] = aten::relu_(%input.22: float[1, 256, 56, 56])
# 	%1180: none = prim::constant()
# 	%1181: int = prim::constant[value = 1]()
# 	%1182: int = prim::constant[value = 1]()
# 	%1183: list[int] = prim::listconstruct(%1181: int, %1182: int)
# 	%1184: int = prim::constant[value = 0]()
# 	%1185: int = prim::constant[value = 0]()
# 	%1186: list[int] = prim::listconstruct(%1184: int, %1185: int)
# 	%1187: int = prim::constant[value = 1]()
# 	%1188: int = prim::constant[value = 1]()
# 	%1189: list[int] = prim::listconstruct(%1187: int, %1188: int)
# 	%1190: bool = prim::constant[value = 0]()
# 	%1191: int = prim::constant[value = 0]()
# 	%1192: int = prim::constant[value = 0]()
# 	%1193: list[int] = prim::listconstruct(%1191: int, %1192: int)
# 	%1194: int = prim::constant[value = 1]()
# 	%1195: bool = prim::constant[value = 0]()
# 	%1196: bool = prim::constant[value = 0]()
# 	%1197: bool = prim::constant[value = 1]()
# 	%input.24: float[1, 64, 56, 56] = aten::_convolution(%input.23: float[1, 256, 56, 56], %49: float[64, 256, 1, 1], %1180: none, %1183: list[int], %1186: list[int], %1189: list[int], %1190: bool, %1193: list[int], %1194: int, %1195: bool, %1196: bool, %1197: bool)
# 	%1199: bool = prim::constant[value = 0]()
# 	%1200: float = prim::constant[value = 0.1]()
# 	%1201: float = prim::constant[value = 1e-05]()
# 	%1202: bool = prim::constant[value = 1]()
# 	%input.25: float[1, 64, 56, 56] = aten::batch_norm(%input.24: float[1, 64, 56, 56], %50: float[64], %51: float[64], %52: float[64], %53: float[64], %1199: bool, %1200: float, %1201: float, %1202: bool)
# 	%input.26: float[1, 64, 56, 56] = aten::relu_(%input.25: float[1, 64, 56, 56])
# 	%1205: none = prim::constant()
# 	%1206: int = prim::constant[value = 1]()
# 	%1207: int = prim::constant[value = 1]()
# 	%1208: list[int] = prim::listconstruct(%1206: int, %1207: int)
# 	%1209: int = prim::constant[value = 1]()
# 	%1210: int = prim::constant[value = 1]()
# 	%1211: list[int] = prim::listconstruct(%1209: int, %1210: int)
# 	%1212: int = prim::constant[value = 1]()
# 	%1213: int = prim::constant[value = 1]()
# 	%1214: list[int] = prim::listconstruct(%1212: int, %1213: int)
# 	%1215: bool = prim::constant[value = 0]()
# 	%1216: int = prim::constant[value = 0]()
# 	%1217: int = prim::constant[value = 0]()
# 	%1218: list[int] = prim::listconstruct(%1216: int, %1217: int)
# 	%1219: int = prim::constant[value = 1]()
# 	%1220: bool = prim::constant[value = 0]()
# 	%1221: bool = prim::constant[value = 0]()
# 	%1222: bool = prim::constant[value = 1]()
# 	%input.27: float[1, 64, 56, 56] = aten::_convolution(%input.26: float[1, 64, 56, 56], %55: float[64, 64, 3, 3], %1205: none, %1208: list[int], %1211: list[int], %1214: list[int], %1215: bool, %1218: list[int], %1219: int, %1220: bool, %1221: bool, %1222: bool)
# 	%1224: bool = prim::constant[value = 0]()
# 	%1225: float = prim::constant[value = 0.1]()
# 	%1226: float = prim::constant[value = 1e-05]()
# 	%1227: bool = prim::constant[value = 1]()
# 	%input.28: float[1, 64, 56, 56] = aten::batch_norm(%input.27: float[1, 64, 56, 56], %56: float[64], %57: float[64], %58: float[64], %59: float[64], %1224: bool, %1225: float, %1226: float, %1227: bool)
# 	%input.29: float[1, 64, 56, 56] = aten::relu_(%input.28: float[1, 64, 56, 56])
# 	%1230: none = prim::constant()
# 	%1231: int = prim::constant[value = 1]()
# 	%1232: int = prim::constant[value = 1]()
# 	%1233: list[int] = prim::listconstruct(%1231: int, %1232: int)
# 	%1234: int = prim::constant[value = 0]()
# 	%1235: int = prim::constant[value = 0]()
# 	%1236: list[int] = prim::listconstruct(%1234: int, %1235: int)
# 	%1237: int = prim::constant[value = 1]()
# 	%1238: int = prim::constant[value = 1]()
# 	%1239: list[int] = prim::listconstruct(%1237: int, %1238: int)
# 	%1240: bool = prim::constant[value = 0]()
# 	%1241: int = prim::constant[value = 0]()
# 	%1242: int = prim::constant[value = 0]()
# 	%1243: list[int] = prim::listconstruct(%1241: int, %1242: int)
# 	%1244: int = prim::constant[value = 1]()
# 	%1245: bool = prim::constant[value = 0]()
# 	%1246: bool = prim::constant[value = 0]()
# 	%1247: bool = prim::constant[value = 1]()
# 	%input.30: float[1, 256, 56, 56] = aten::_convolution(%input.29: float[1, 64, 56, 56], %61: float[256, 64, 1, 1], %1230: none, %1233: list[int], %1236: list[int], %1239: list[int], %1240: bool, %1243: list[int], %1244: int, %1245: bool, %1246: bool, %1247: bool)
# 	%1249: bool = prim::constant[value = 0]()
# 	%1250: float = prim::constant[value = 0.1]()
# 	%1251: float = prim::constant[value = 1e-05]()
# 	%1252: bool = prim::constant[value = 1]()
# 	%1253: float[1, 256, 56, 56] = aten::batch_norm(%input.30: float[1, 256, 56, 56], %62: float[256], %63: float[256], %64: float[256], %65: float[256], %1249: bool, %1250: float, %1251: float, %1252: bool)
# 	%1254: int = prim::constant[value = 1]()
# 	%input.31: float[1, 256, 56, 56] = aten::add_(%1253: float[1, 256, 56, 56], %input.23: float[1, 256, 56, 56], %1254: int)
# 	%input.32: float[1, 256, 56, 56] = aten::relu_(%input.31: float[1, 256, 56, 56])
# 	%1257: none = prim::constant()
# 	%1258: int = prim::constant[value = 1]()
# 	%1259: int = prim::constant[value = 1]()
# 	%1260: list[int] = prim::listconstruct(%1258: int, %1259: int)
# 	%1261: int = prim::constant[value = 0]()
# 	%1262: int = prim::constant[value = 0]()
# 	%1263: list[int] = prim::listconstruct(%1261: int, %1262: int)
# 	%1264: int = prim::constant[value = 1]()
# 	%1265: int = prim::constant[value = 1]()
# 	%1266: list[int] = prim::listconstruct(%1264: int, %1265: int)
# 	%1267: bool = prim::constant[value = 0]()
# 	%1268: int = prim::constant[value = 0]()
# 	%1269: int = prim::constant[value = 0]()
# 	%1270: list[int] = prim::listconstruct(%1268: int, %1269: int)
# 	%1271: int = prim::constant[value = 1]()
# 	%1272: bool = prim::constant[value = 0]()
# 	%1273: bool = prim::constant[value = 0]()
# 	%1274: bool = prim::constant[value = 1]()
# 	%input.33: float[1, 128, 56, 56] = aten::_convolution(%input.32: float[1, 256, 56, 56], %67: float[128, 256, 1, 1], %1257: none, %1260: list[int], %1263: list[int], %1266: list[int], %1267: bool, %1270: list[int], %1271: int, %1272: bool, %1273: bool, %1274: bool)
# 	%1276: bool = prim::constant[value = 0]()
# 	%1277: float = prim::constant[value = 0.1]()
# 	%1278: float = prim::constant[value = 1e-05]()
# 	%1279: bool = prim::constant[value = 1]()
# 	%input.34: float[1, 128, 56, 56] = aten::batch_norm(%input.33: float[1, 128, 56, 56], %68: float[128], %69: float[128], %70: float[128], %71: float[128], %1276: bool, %1277: float, %1278: float, %1279: bool)
# 	%input.35: float[1, 128, 56, 56] = aten::relu_(%input.34: float[1, 128, 56, 56])
# 	%1282: none = prim::constant()
# 	%1283: int = prim::constant[value = 2]()
# 	%1284: int = prim::constant[value = 2]()
# 	%1285: list[int] = prim::listconstruct(%1283: int, %1284: int)
# 	%1286: int = prim::constant[value = 1]()
# 	%1287: int = prim::constant[value = 1]()
# 	%1288: list[int] = prim::listconstruct(%1286: int, %1287: int)
# 	%1289: int = prim::constant[value = 1]()
# 	%1290: int = prim::constant[value = 1]()
# 	%1291: list[int] = prim::listconstruct(%1289: int, %1290: int)
# 	%1292: bool = prim::constant[value = 0]()
# 	%1293: int = prim::constant[value = 0]()
# 	%1294: int = prim::constant[value = 0]()
# 	%1295: list[int] = prim::listconstruct(%1293: int, %1294: int)
# 	%1296: int = prim::constant[value = 1]()
# 	%1297: bool = prim::constant[value = 0]()
# 	%1298: bool = prim::constant[value = 0]()
# 	%1299: bool = prim::constant[value = 1]()
# 	%input.36: float[1, 128, 28, 28] = aten::_convolution(%input.35: float[1, 128, 56, 56], %73: float[128, 128, 3, 3], %1282: none, %1285: list[int], %1288: list[int], %1291: list[int], %1292: bool, %1295: list[int], %1296: int, %1297: bool, %1298: bool, %1299: bool)
# 	%1301: bool = prim::constant[value = 0]()
# 	%1302: float = prim::constant[value = 0.1]()
# 	%1303: float = prim::constant[value = 1e-05]()
# 	%1304: bool = prim::constant[value = 1]()
# 	%input.37: float[1, 128, 28, 28] = aten::batch_norm(%input.36: float[1, 128, 28, 28], %74: float[128], %75: float[128], %76: float[128], %77: float[128], %1301: bool, %1302: float, %1303: float, %1304: bool)
# 	%input.38: float[1, 128, 28, 28] = aten::relu_(%input.37: float[1, 128, 28, 28])
# 	%1307: none = prim::constant()
# 	%1308: int = prim::constant[value = 1]()
# 	%1309: int = prim::constant[value = 1]()
# 	%1310: list[int] = prim::listconstruct(%1308: int, %1309: int)
# 	%1311: int = prim::constant[value = 0]()
# 	%1312: int = prim::constant[value = 0]()
# 	%1313: list[int] = prim::listconstruct(%1311: int, %1312: int)
# 	%1314: int = prim::constant[value = 1]()
# 	%1315: int = prim::constant[value = 1]()
# 	%1316: list[int] = prim::listconstruct(%1314: int, %1315: int)
# 	%1317: bool = prim::constant[value = 0]()
# 	%1318: int = prim::constant[value = 0]()
# 	%1319: int = prim::constant[value = 0]()
# 	%1320: list[int] = prim::listconstruct(%1318: int, %1319: int)
# 	%1321: int = prim::constant[value = 1]()
# 	%1322: bool = prim::constant[value = 0]()
# 	%1323: bool = prim::constant[value = 0]()
# 	%1324: bool = prim::constant[value = 1]()
# 	%input.39: float[1, 512, 28, 28] = aten::_convolution(%input.38: float[1, 128, 28, 28], %79: float[512, 128, 1, 1], %1307: none, %1310: list[int], %1313: list[int], %1316: list[int], %1317: bool, %1320: list[int], %1321: int, %1322: bool, %1323: bool, %1324: bool)
# 	%1326: bool = prim::constant[value = 0]()
# 	%1327: float = prim::constant[value = 0.1]()
# 	%1328: float = prim::constant[value = 1e-05]()
# 	%1329: bool = prim::constant[value = 1]()
# 	%1330: float[1, 512, 28, 28] = aten::batch_norm(%input.39: float[1, 512, 28, 28], %80: float[512], %81: float[512], %82: float[512], %83: float[512], %1326: bool, %1327: float, %1328: float, %1329: bool)
# 	%1331: none = prim::constant()
# 	%1332: int = prim::constant[value = 2]()
# 	%1333: int = prim::constant[value = 2]()
# 	%1334: list[int] = prim::listconstruct(%1332: int, %1333: int)
# 	%1335: int = prim::constant[value = 0]()
# 	%1336: int = prim::constant[value = 0]()
# 	%1337: list[int] = prim::listconstruct(%1335: int, %1336: int)
# 	%1338: int = prim::constant[value = 1]()
# 	%1339: int = prim::constant[value = 1]()
# 	%1340: list[int] = prim::listconstruct(%1338: int, %1339: int)
# 	%1341: bool = prim::constant[value = 0]()
# 	%1342: int = prim::constant[value = 0]()
# 	%1343: int = prim::constant[value = 0]()
# 	%1344: list[int] = prim::listconstruct(%1342: int, %1343: int)
# 	%1345: int = prim::constant[value = 1]()
# 	%1346: bool = prim::constant[value = 0]()
# 	%1347: bool = prim::constant[value = 0]()
# 	%1348: bool = prim::constant[value = 1]()
# 	%input.40: float[1, 512, 28, 28] = aten::_convolution(%input.32: float[1, 256, 56, 56], %85: float[512, 256, 1, 1], %1331: none, %1334: list[int], %1337: list[int], %1340: list[int], %1341: bool, %1344: list[int], %1345: int, %1346: bool, %1347: bool, %1348: bool)
# 	%1350: bool = prim::constant[value = 0]()
# 	%1351: float = prim::constant[value = 0.1]()
# 	%1352: float = prim::constant[value = 1e-05]()
# 	%1353: bool = prim::constant[value = 1]()
# 	%1354: float[1, 512, 28, 28] = aten::batch_norm(%input.40: float[1, 512, 28, 28], %86: float[512], %87: float[512], %88: float[512], %89: float[512], %1350: bool, %1351: float, %1352: float, %1353: bool)
# 	%1355: int = prim::constant[value = 1]()
# 	%input.41: float[1, 512, 28, 28] = aten::add_(%1330: float[1, 512, 28, 28], %1354: float[1, 512, 28, 28], %1355: int)
# 	%input.42: float[1, 512, 28, 28] = aten::relu_(%input.41: float[1, 512, 28, 28])
# 	%1358: none = prim::constant()
# 	%1359: int = prim::constant[value = 1]()
# 	%1360: int = prim::constant[value = 1]()
# 	%1361: list[int] = prim::listconstruct(%1359: int, %1360: int)
# 	%1362: int = prim::constant[value = 0]()
# 	%1363: int = prim::constant[value = 0]()
# 	%1364: list[int] = prim::listconstruct(%1362: int, %1363: int)
# 	%1365: int = prim::constant[value = 1]()
# 	%1366: int = prim::constant[value = 1]()
# 	%1367: list[int] = prim::listconstruct(%1365: int, %1366: int)
# 	%1368: bool = prim::constant[value = 0]()
# 	%1369: int = prim::constant[value = 0]()
# 	%1370: int = prim::constant[value = 0]()
# 	%1371: list[int] = prim::listconstruct(%1369: int, %1370: int)
# 	%1372: int = prim::constant[value = 1]()
# 	%1373: bool = prim::constant[value = 0]()
# 	%1374: bool = prim::constant[value = 0]()
# 	%1375: bool = prim::constant[value = 1]()
# 	%input.43: float[1, 128, 28, 28] = aten::_convolution(%input.42: float[1, 512, 28, 28], %91: float[128, 512, 1, 1], %1358: none, %1361: list[int], %1364: list[int], %1367: list[int], %1368: bool, %1371: list[int], %1372: int, %1373: bool, %1374: bool, %1375: bool)
# 	%1377: bool = prim::constant[value = 0]()
# 	%1378: float = prim::constant[value = 0.1]()
# 	%1379: float = prim::constant[value = 1e-05]()
# 	%1380: bool = prim::constant[value = 1]()
# 	%input.44: float[1, 128, 28, 28] = aten::batch_norm(%input.43: float[1, 128, 28, 28], %92: float[128], %93: float[128], %94: float[128], %95: float[128], %1377: bool, %1378: float, %1379: float, %1380: bool)
# 	%input.45: float[1, 128, 28, 28] = aten::relu_(%input.44: float[1, 128, 28, 28])
# 	%1383: none = prim::constant()
# 	%1384: int = prim::constant[value = 1]()
# 	%1385: int = prim::constant[value = 1]()
# 	%1386: list[int] = prim::listconstruct(%1384: int, %1385: int)
# 	%1387: int = prim::constant[value = 1]()
# 	%1388: int = prim::constant[value = 1]()
# 	%1389: list[int] = prim::listconstruct(%1387: int, %1388: int)
# 	%1390: int = prim::constant[value = 1]()
# 	%1391: int = prim::constant[value = 1]()
# 	%1392: list[int] = prim::listconstruct(%1390: int, %1391: int)
# 	%1393: bool = prim::constant[value = 0]()
# 	%1394: int = prim::constant[value = 0]()
# 	%1395: int = prim::constant[value = 0]()
# 	%1396: list[int] = prim::listconstruct(%1394: int, %1395: int)
# 	%1397: int = prim::constant[value = 1]()
# 	%1398: bool = prim::constant[value = 0]()
# 	%1399: bool = prim::constant[value = 0]()
# 	%1400: bool = prim::constant[value = 1]()
# 	%input.46: float[1, 128, 28, 28] = aten::_convolution(%input.45: float[1, 128, 28, 28], %97: float[128, 128, 3, 3], %1383: none, %1386: list[int], %1389: list[int], %1392: list[int], %1393: bool, %1396: list[int], %1397: int, %1398: bool, %1399: bool, %1400: bool)
# 	%1402: bool = prim::constant[value = 0]()
# 	%1403: float = prim::constant[value = 0.1]()
# 	%1404: float = prim::constant[value = 1e-05]()
# 	%1405: bool = prim::constant[value = 1]()
# 	%input.47: float[1, 128, 28, 28] = aten::batch_norm(%input.46: float[1, 128, 28, 28], %98: float[128], %99: float[128], %100: float[128], %101: float[128], %1402: bool, %1403: float, %1404: float, %1405: bool)
# 	%input.48: float[1, 128, 28, 28] = aten::relu_(%input.47: float[1, 128, 28, 28])
# 	%1408: none = prim::constant()
# 	%1409: int = prim::constant[value = 1]()
# 	%1410: int = prim::constant[value = 1]()
# 	%1411: list[int] = prim::listconstruct(%1409: int, %1410: int)
# 	%1412: int = prim::constant[value = 0]()
# 	%1413: int = prim::constant[value = 0]()
# 	%1414: list[int] = prim::listconstruct(%1412: int, %1413: int)
# 	%1415: int = prim::constant[value = 1]()
# 	%1416: int = prim::constant[value = 1]()
# 	%1417: list[int] = prim::listconstruct(%1415: int, %1416: int)
# 	%1418: bool = prim::constant[value = 0]()
# 	%1419: int = prim::constant[value = 0]()
# 	%1420: int = prim::constant[value = 0]()
# 	%1421: list[int] = prim::listconstruct(%1419: int, %1420: int)
# 	%1422: int = prim::constant[value = 1]()
# 	%1423: bool = prim::constant[value = 0]()
# 	%1424: bool = prim::constant[value = 0]()
# 	%1425: bool = prim::constant[value = 1]()
# 	%input.49: float[1, 512, 28, 28] = aten::_convolution(%input.48: float[1, 128, 28, 28], %103: float[512, 128, 1, 1], %1408: none, %1411: list[int], %1414: list[int], %1417: list[int], %1418: bool, %1421: list[int], %1422: int, %1423: bool, %1424: bool, %1425: bool)
# 	%1427: bool = prim::constant[value = 0]()
# 	%1428: float = prim::constant[value = 0.1]()
# 	%1429: float = prim::constant[value = 1e-05]()
# 	%1430: bool = prim::constant[value = 1]()
# 	%1431: float[1, 512, 28, 28] = aten::batch_norm(%input.49: float[1, 512, 28, 28], %104: float[512], %105: float[512], %106: float[512], %107: float[512], %1427: bool, %1428: float, %1429: float, %1430: bool)
# 	%1432: int = prim::constant[value = 1]()
# 	%input.50: float[1, 512, 28, 28] = aten::add_(%1431: float[1, 512, 28, 28], %input.42: float[1, 512, 28, 28], %1432: int)
# 	%input.51: float[1, 512, 28, 28] = aten::relu_(%input.50: float[1, 512, 28, 28])
# 	%1435: none = prim::constant()
# 	%1436: int = prim::constant[value = 1]()
# 	%1437: int = prim::constant[value = 1]()
# 	%1438: list[int] = prim::listconstruct(%1436: int, %1437: int)
# 	%1439: int = prim::constant[value = 0]()
# 	%1440: int = prim::constant[value = 0]()
# 	%1441: list[int] = prim::listconstruct(%1439: int, %1440: int)
# 	%1442: int = prim::constant[value = 1]()
# 	%1443: int = prim::constant[value = 1]()
# 	%1444: list[int] = prim::listconstruct(%1442: int, %1443: int)
# 	%1445: bool = prim::constant[value = 0]()
# 	%1446: int = prim::constant[value = 0]()
# 	%1447: int = prim::constant[value = 0]()
# 	%1448: list[int] = prim::listconstruct(%1446: int, %1447: int)
# 	%1449: int = prim::constant[value = 1]()
# 	%1450: bool = prim::constant[value = 0]()
# 	%1451: bool = prim::constant[value = 0]()
# 	%1452: bool = prim::constant[value = 1]()
# 	%input.52: float[1, 128, 28, 28] = aten::_convolution(%input.51: float[1, 512, 28, 28], %109: float[128, 512, 1, 1], %1435: none, %1438: list[int], %1441: list[int], %1444: list[int], %1445: bool, %1448: list[int], %1449: int, %1450: bool, %1451: bool, %1452: bool)
# 	%1454: bool = prim::constant[value = 0]()
# 	%1455: float = prim::constant[value = 0.1]()
# 	%1456: float = prim::constant[value = 1e-05]()
# 	%1457: bool = prim::constant[value = 1]()
# 	%input.53: float[1, 128, 28, 28] = aten::batch_norm(%input.52: float[1, 128, 28, 28], %110: float[128], %111: float[128], %112: float[128], %113: float[128], %1454: bool, %1455: float, %1456: float, %1457: bool)
# 	%input.54: float[1, 128, 28, 28] = aten::relu_(%input.53: float[1, 128, 28, 28])
# 	%1460: none = prim::constant()
# 	%1461: int = prim::constant[value = 1]()
# 	%1462: int = prim::constant[value = 1]()
# 	%1463: list[int] = prim::listconstruct(%1461: int, %1462: int)
# 	%1464: int = prim::constant[value = 1]()
# 	%1465: int = prim::constant[value = 1]()
# 	%1466: list[int] = prim::listconstruct(%1464: int, %1465: int)
# 	%1467: int = prim::constant[value = 1]()
# 	%1468: int = prim::constant[value = 1]()
# 	%1469: list[int] = prim::listconstruct(%1467: int, %1468: int)
# 	%1470: bool = prim::constant[value = 0]()
# 	%1471: int = prim::constant[value = 0]()
# 	%1472: int = prim::constant[value = 0]()
# 	%1473: list[int] = prim::listconstruct(%1471: int, %1472: int)
# 	%1474: int = prim::constant[value = 1]()
# 	%1475: bool = prim::constant[value = 0]()
# 	%1476: bool = prim::constant[value = 0]()
# 	%1477: bool = prim::constant[value = 1]()
# 	%input.55: float[1, 128, 28, 28] = aten::_convolution(%input.54: float[1, 128, 28, 28], %115: float[128, 128, 3, 3], %1460: none, %1463: list[int], %1466: list[int], %1469: list[int], %1470: bool, %1473: list[int], %1474: int, %1475: bool, %1476: bool, %1477: bool)
# 	%1479: bool = prim::constant[value = 0]()
# 	%1480: float = prim::constant[value = 0.1]()
# 	%1481: float = prim::constant[value = 1e-05]()
# 	%1482: bool = prim::constant[value = 1]()
# 	%input.56: float[1, 128, 28, 28] = aten::batch_norm(%input.55: float[1, 128, 28, 28], %116: float[128], %117: float[128], %118: float[128], %119: float[128], %1479: bool, %1480: float, %1481: float, %1482: bool)
# 	%input.57: float[1, 128, 28, 28] = aten::relu_(%input.56: float[1, 128, 28, 28])
# 	%1485: none = prim::constant()
# 	%1486: int = prim::constant[value = 1]()
# 	%1487: int = prim::constant[value = 1]()
# 	%1488: list[int] = prim::listconstruct(%1486: int, %1487: int)
# 	%1489: int = prim::constant[value = 0]()
# 	%1490: int = prim::constant[value = 0]()
# 	%1491: list[int] = prim::listconstruct(%1489: int, %1490: int)
# 	%1492: int = prim::constant[value = 1]()
# 	%1493: int = prim::constant[value = 1]()
# 	%1494: list[int] = prim::listconstruct(%1492: int, %1493: int)
# 	%1495: bool = prim::constant[value = 0]()
# 	%1496: int = prim::constant[value = 0]()
# 	%1497: int = prim::constant[value = 0]()
# 	%1498: list[int] = prim::listconstruct(%1496: int, %1497: int)
# 	%1499: int = prim::constant[value = 1]()
# 	%1500: bool = prim::constant[value = 0]()
# 	%1501: bool = prim::constant[value = 0]()
# 	%1502: bool = prim::constant[value = 1]()
# 	%input.58: float[1, 512, 28, 28] = aten::_convolution(%input.57: float[1, 128, 28, 28], %121: float[512, 128, 1, 1], %1485: none, %1488: list[int], %1491: list[int], %1494: list[int], %1495: bool, %1498: list[int], %1499: int, %1500: bool, %1501: bool, %1502: bool)
# 	%1504: bool = prim::constant[value = 0]()
# 	%1505: float = prim::constant[value = 0.1]()
# 	%1506: float = prim::constant[value = 1e-05]()
# 	%1507: bool = prim::constant[value = 1]()
# 	%1508: float[1, 512, 28, 28] = aten::batch_norm(%input.58: float[1, 512, 28, 28], %122: float[512], %123: float[512], %124: float[512], %125: float[512], %1504: bool, %1505: float, %1506: float, %1507: bool)
# 	%1509: int = prim::constant[value = 1]()
# 	%input.59: float[1, 512, 28, 28] = aten::add_(%1508: float[1, 512, 28, 28], %input.51: float[1, 512, 28, 28], %1509: int)
# 	%input.60: float[1, 512, 28, 28] = aten::relu_(%input.59: float[1, 512, 28, 28])
# 	%1512: none = prim::constant()
# 	%1513: int = prim::constant[value = 1]()
# 	%1514: int = prim::constant[value = 1]()
# 	%1515: list[int] = prim::listconstruct(%1513: int, %1514: int)
# 	%1516: int = prim::constant[value = 0]()
# 	%1517: int = prim::constant[value = 0]()
# 	%1518: list[int] = prim::listconstruct(%1516: int, %1517: int)
# 	%1519: int = prim::constant[value = 1]()
# 	%1520: int = prim::constant[value = 1]()
# 	%1521: list[int] = prim::listconstruct(%1519: int, %1520: int)
# 	%1522: bool = prim::constant[value = 0]()
# 	%1523: int = prim::constant[value = 0]()
# 	%1524: int = prim::constant[value = 0]()
# 	%1525: list[int] = prim::listconstruct(%1523: int, %1524: int)
# 	%1526: int = prim::constant[value = 1]()
# 	%1527: bool = prim::constant[value = 0]()
# 	%1528: bool = prim::constant[value = 0]()
# 	%1529: bool = prim::constant[value = 1]()
# 	%input.61: float[1, 128, 28, 28] = aten::_convolution(%input.60: float[1, 512, 28, 28], %127: float[128, 512, 1, 1], %1512: none, %1515: list[int], %1518: list[int], %1521: list[int], %1522: bool, %1525: list[int], %1526: int, %1527: bool, %1528: bool, %1529: bool)
# 	%1531: bool = prim::constant[value = 0]()
# 	%1532: float = prim::constant[value = 0.1]()
# 	%1533: float = prim::constant[value = 1e-05]()
# 	%1534: bool = prim::constant[value = 1]()
# 	%input.62: float[1, 128, 28, 28] = aten::batch_norm(%input.61: float[1, 128, 28, 28], %128: float[128], %129: float[128], %130: float[128], %131: float[128], %1531: bool, %1532: float, %1533: float, %1534: bool)
# 	%input.63: float[1, 128, 28, 28] = aten::relu_(%input.62: float[1, 128, 28, 28])
# 	%1537: none = prim::constant()
# 	%1538: int = prim::constant[value = 1]()
# 	%1539: int = prim::constant[value = 1]()
# 	%1540: list[int] = prim::listconstruct(%1538: int, %1539: int)
# 	%1541: int = prim::constant[value = 1]()
# 	%1542: int = prim::constant[value = 1]()
# 	%1543: list[int] = prim::listconstruct(%1541: int, %1542: int)
# 	%1544: int = prim::constant[value = 1]()
# 	%1545: int = prim::constant[value = 1]()
# 	%1546: list[int] = prim::listconstruct(%1544: int, %1545: int)
# 	%1547: bool = prim::constant[value = 0]()
# 	%1548: int = prim::constant[value = 0]()
# 	%1549: int = prim::constant[value = 0]()
# 	%1550: list[int] = prim::listconstruct(%1548: int, %1549: int)
# 	%1551: int = prim::constant[value = 1]()
# 	%1552: bool = prim::constant[value = 0]()
# 	%1553: bool = prim::constant[value = 0]()
# 	%1554: bool = prim::constant[value = 1]()
# 	%input.64: float[1, 128, 28, 28] = aten::_convolution(%input.63: float[1, 128, 28, 28], %133: float[128, 128, 3, 3], %1537: none, %1540: list[int], %1543: list[int], %1546: list[int], %1547: bool, %1550: list[int], %1551: int, %1552: bool, %1553: bool, %1554: bool)
# 	%1556: bool = prim::constant[value = 0]()
# 	%1557: float = prim::constant[value = 0.1]()
# 	%1558: float = prim::constant[value = 1e-05]()
# 	%1559: bool = prim::constant[value = 1]()
# 	%input.65: float[1, 128, 28, 28] = aten::batch_norm(%input.64: float[1, 128, 28, 28], %134: float[128], %135: float[128], %136: float[128], %137: float[128], %1556: bool, %1557: float, %1558: float, %1559: bool)
# 	%input.66: float[1, 128, 28, 28] = aten::relu_(%input.65: float[1, 128, 28, 28])
# 	%1562: none = prim::constant()
# 	%1563: int = prim::constant[value = 1]()
# 	%1564: int = prim::constant[value = 1]()
# 	%1565: list[int] = prim::listconstruct(%1563: int, %1564: int)
# 	%1566: int = prim::constant[value = 0]()
# 	%1567: int = prim::constant[value = 0]()
# 	%1568: list[int] = prim::listconstruct(%1566: int, %1567: int)
# 	%1569: int = prim::constant[value = 1]()
# 	%1570: int = prim::constant[value = 1]()
# 	%1571: list[int] = prim::listconstruct(%1569: int, %1570: int)
# 	%1572: bool = prim::constant[value = 0]()
# 	%1573: int = prim::constant[value = 0]()
# 	%1574: int = prim::constant[value = 0]()
# 	%1575: list[int] = prim::listconstruct(%1573: int, %1574: int)
# 	%1576: int = prim::constant[value = 1]()
# 	%1577: bool = prim::constant[value = 0]()
# 	%1578: bool = prim::constant[value = 0]()
# 	%1579: bool = prim::constant[value = 1]()
# 	%input.67: float[1, 512, 28, 28] = aten::_convolution(%input.66: float[1, 128, 28, 28], %139: float[512, 128, 1, 1], %1562: none, %1565: list[int], %1568: list[int], %1571: list[int], %1572: bool, %1575: list[int], %1576: int, %1577: bool, %1578: bool, %1579: bool)
# 	%1581: bool = prim::constant[value = 0]()
# 	%1582: float = prim::constant[value = 0.1]()
# 	%1583: float = prim::constant[value = 1e-05]()
# 	%1584: bool = prim::constant[value = 1]()
# 	%1585: float[1, 512, 28, 28] = aten::batch_norm(%input.67: float[1, 512, 28, 28], %140: float[512], %141: float[512], %142: float[512], %143: float[512], %1581: bool, %1582: float, %1583: float, %1584: bool)
# 	%1586: int = prim::constant[value = 1]()
# 	%input.68: float[1, 512, 28, 28] = aten::add_(%1585: float[1, 512, 28, 28], %input.60: float[1, 512, 28, 28], %1586: int)
# 	%input.69: float[1, 512, 28, 28] = aten::relu_(%input.68: float[1, 512, 28, 28])
# 	%1589: none = prim::constant()
# 	%1590: int = prim::constant[value = 1]()
# 	%1591: int = prim::constant[value = 1]()
# 	%1592: list[int] = prim::listconstruct(%1590: int, %1591: int)
# 	%1593: int = prim::constant[value = 0]()
# 	%1594: int = prim::constant[value = 0]()
# 	%1595: list[int] = prim::listconstruct(%1593: int, %1594: int)
# 	%1596: int = prim::constant[value = 1]()
# 	%1597: int = prim::constant[value = 1]()
# 	%1598: list[int] = prim::listconstruct(%1596: int, %1597: int)
# 	%1599: bool = prim::constant[value = 0]()
# 	%1600: int = prim::constant[value = 0]()
# 	%1601: int = prim::constant[value = 0]()
# 	%1602: list[int] = prim::listconstruct(%1600: int, %1601: int)
# 	%1603: int = prim::constant[value = 1]()
# 	%1604: bool = prim::constant[value = 0]()
# 	%1605: bool = prim::constant[value = 0]()
# 	%1606: bool = prim::constant[value = 1]()
# 	%input.70: float[1, 256, 28, 28] = aten::_convolution(%input.69: float[1, 512, 28, 28], %145: float[256, 512, 1, 1], %1589: none, %1592: list[int], %1595: list[int], %1598: list[int], %1599: bool, %1602: list[int], %1603: int, %1604: bool, %1605: bool, %1606: bool)
# 	%1608: bool = prim::constant[value = 0]()
# 	%1609: float = prim::constant[value = 0.1]()
# 	%1610: float = prim::constant[value = 1e-05]()
# 	%1611: bool = prim::constant[value = 1]()
# 	%input.71: float[1, 256, 28, 28] = aten::batch_norm(%input.70: float[1, 256, 28, 28], %146: float[256], %147: float[256], %148: float[256], %149: float[256], %1608: bool, %1609: float, %1610: float, %1611: bool)
# 	%input.72: float[1, 256, 28, 28] = aten::relu_(%input.71: float[1, 256, 28, 28])
# 	%1614: none = prim::constant()
# 	%1615: int = prim::constant[value = 2]()
# 	%1616: int = prim::constant[value = 2]()
# 	%1617: list[int] = prim::listconstruct(%1615: int, %1616: int)
# 	%1618: int = prim::constant[value = 1]()
# 	%1619: int = prim::constant[value = 1]()
# 	%1620: list[int] = prim::listconstruct(%1618: int, %1619: int)
# 	%1621: int = prim::constant[value = 1]()
# 	%1622: int = prim::constant[value = 1]()
# 	%1623: list[int] = prim::listconstruct(%1621: int, %1622: int)
# 	%1624: bool = prim::constant[value = 0]()
# 	%1625: int = prim::constant[value = 0]()
# 	%1626: int = prim::constant[value = 0]()
# 	%1627: list[int] = prim::listconstruct(%1625: int, %1626: int)
# 	%1628: int = prim::constant[value = 1]()
# 	%1629: bool = prim::constant[value = 0]()
# 	%1630: bool = prim::constant[value = 0]()
# 	%1631: bool = prim::constant[value = 1]()
# 	%input.73: float[1, 256, 14, 14] = aten::_convolution(%input.72: float[1, 256, 28, 28], %151: float[256, 256, 3, 3], %1614: none, %1617: list[int], %1620: list[int], %1623: list[int], %1624: bool, %1627: list[int], %1628: int, %1629: bool, %1630: bool, %1631: bool)
# 	%1633: bool = prim::constant[value = 0]()
# 	%1634: float = prim::constant[value = 0.1]()
# 	%1635: float = prim::constant[value = 1e-05]()
# 	%1636: bool = prim::constant[value = 1]()
# ...
# 	%input.128: float[1, 1024, 7, 7] = aten::_convolution(%input.127: float[1, 1024, 14, 14], %265: float[1024, 1024, 3, 3], %2100: none, %2103: list[int], %2106: list[int], %2109: list[int], %2110: bool, %2113: list[int], %2114: int, %2115: bool, %2116: bool, %2117: bool)
# 	%2119: bool = prim::constant[value = 0]()
# 	%2120: float = prim::constant[value = 0.1]()
# 	%2121: float = prim::constant[value = 1e-05]()
# 	%2122: bool = prim::constant[value = 1]()
# 	%input.129: float[1, 1024, 7, 7] = aten::batch_norm(%input.128: float[1, 1024, 7, 7], %266: float[1024], %267: float[1024], %268: float[1024], %269: float[1024], %2119: bool, %2120: float, %2121: float, %2122: bool)
# 	%input.130: float[1, 1024, 7, 7] = aten::relu_(%input.129: float[1, 1024, 7, 7])
# 	%2125: none = prim::constant()
# 	%2126: int = prim::constant[value = 1]()
# 	%2127: int = prim::constant[value = 1]()
# 	%2128: list[int] = prim::listconstruct(%2126: int, %2127: int)
# 	%2129: int = prim::constant[value = 0]()
# 	%2130: int = prim::constant[value = 0]()
# 	%2131: list[int] = prim::listconstruct(%2129: int, %2130: int)
# 	%2132: int = prim::constant[value = 1]()
# 	%2133: int = prim::constant[value = 1]()
# 	%2134: list[int] = prim::listconstruct(%2132: int, %2133: int)
# 	%2135: bool = prim::constant[value = 0]()
# 	%2136: int = prim::constant[value = 0]()
# 	%2137: int = prim::constant[value = 0]()
# 	%2138: list[int] = prim::listconstruct(%2136: int, %2137: int)
# 	%2139: int = prim::constant[value = 1]()
# 	%2140: bool = prim::constant[value = 0]()
# 	%2141: bool = prim::constant[value = 0]()
# 	%2142: bool = prim::constant[value = 1]()
# 	%input.131: float[1, 2048, 7, 7] = aten::_convolution(%input.130: float[1, 1024, 7, 7], %271: float[2048, 1024, 1, 1], %2125: none, %2128: list[int], %2131: list[int], %2134: list[int], %2135: bool, %2138: list[int], %2139: int, %2140: bool, %2141: bool, %2142: bool)
# 	%2144: bool = prim::constant[value = 0]()
# 	%2145: float = prim::constant[value = 0.1]()
# 	%2146: float = prim::constant[value = 1e-05]()
# 	%2147: bool = prim::constant[value = 1]()
# 	%2148: float[1, 2048, 7, 7] = aten::batch_norm(%input.131: float[1, 2048, 7, 7], %272: float[2048], %273: float[2048], %274: float[2048], %275: float[2048], %2144: bool, %2145: float, %2146: float, %2147: bool)
# 	%2149: none = prim::constant()
# 	%2150: int = prim::constant[value = 2]()
# 	%2151: int = prim::constant[value = 2]()
# 	%2152: list[int] = prim::listconstruct(%2150: int, %2151: int)
# 	%2153: int = prim::constant[value = 0]()
# 	%2154: int = prim::constant[value = 0]()
# 	%2155: list[int] = prim::listconstruct(%2153: int, %2154: int)
# 	%2156: int = prim::constant[value = 1]()
# 	%2157: int = prim::constant[value = 1]()
# 	%2158: list[int] = prim::listconstruct(%2156: int, %2157: int)
# 	%2159: bool = prim::constant[value = 0]()
# 	%2160: int = prim::constant[value = 0]()
# 	%2161: int = prim::constant[value = 0]()
# 	%2162: list[int] = prim::listconstruct(%2160: int, %2161: int)
# 	%2163: int = prim::constant[value = 1]()
# 	%2164: bool = prim::constant[value = 0]()
# 	%2165: bool = prim::constant[value = 0]()
# 	%2166: bool = prim::constant[value = 1]()
# 	%input.132: float[1, 2048, 7, 7] = aten::_convolution(%input.124: float[1, 1024, 14, 14], %277: float[2048, 1024, 1, 1], %2149: none, %2152: list[int], %2155: list[int], %2158: list[int], %2159: bool, %2162: list[int], %2163: int, %2164: bool, %2165: bool, %2166: bool)
# 	%2168: bool = prim::constant[value = 0]()
# 	%2169: float = prim::constant[value = 0.1]()
# 	%2170: float = prim::constant[value = 1e-05]()
# 	%2171: bool = prim::constant[value = 1]()
# 	%2172: float[1, 2048, 7, 7] = aten::batch_norm(%input.132: float[1, 2048, 7, 7], %278: float[2048], %279: float[2048], %280: float[2048], %281: float[2048], %2168: bool, %2169: float, %2170: float, %2171: bool)
# 	%2173: int = prim::constant[value = 1]()
# 	%input.133: float[1, 2048, 7, 7] = aten::add_(%2148: float[1, 2048, 7, 7], %2172: float[1, 2048, 7, 7], %2173: int)
# 	%input.134: float[1, 2048, 7, 7] = aten::relu_(%input.133: float[1, 2048, 7, 7])
# 	%2176: none = prim::constant()
# 	%2177: int = prim::constant[value = 1]()
# 	%2178: int = prim::constant[value = 1]()
# 	%2179: list[int] = prim::listconstruct(%2177: int, %2178: int)
# 	%2180: int = prim::constant[value = 0]()
# 	%2181: int = prim::constant[value = 0]()
# 	%2182: list[int] = prim::listconstruct(%2180: int, %2181: int)
# 	%2183: int = prim::constant[value = 1]()
# 	%2184: int = prim::constant[value = 1]()
# 	%2185: list[int] = prim::listconstruct(%2183: int, %2184: int)
# 	%2186: bool = prim::constant[value = 0]()
# 	%2187: int = prim::constant[value = 0]()
# 	%2188: int = prim::constant[value = 0]()
# 	%2189: list[int] = prim::listconstruct(%2187: int, %2188: int)
# 	%2190: int = prim::constant[value = 1]()
# 	%2191: bool = prim::constant[value = 0]()
# 	%2192: bool = prim::constant[value = 0]()
# 	%2193: bool = prim::constant[value = 1]()
# 	%input.135: float[1, 1024, 7, 7] = aten::_convolution(%input.134: float[1, 2048, 7, 7], %283: float[1024, 2048, 1, 1], %2176: none, %2179: list[int], %2182: list[int], %2185: list[int], %2186: bool, %2189: list[int], %2190: int, %2191: bool, %2192: bool, %2193: bool)
# 	%2195: bool = prim::constant[value = 0]()
# 	%2196: float = prim::constant[value = 0.1]()
# 	%2197: float = prim::constant[value = 1e-05]()
# 	%2198: bool = prim::constant[value = 1]()
# 	%input.136: float[1, 1024, 7, 7] = aten::batch_norm(%input.135: float[1, 1024, 7, 7], %284: float[1024], %285: float[1024], %286: float[1024], %287: float[1024], %2195: bool, %2196: float, %2197: float, %2198: bool)
# 	%input.137: float[1, 1024, 7, 7] = aten::relu_(%input.136: float[1, 1024, 7, 7])
# 	%2201: none = prim::constant()
# 	%2202: int = prim::constant[value = 1]()
# 	%2203: int = prim::constant[value = 1]()
# 	%2204: list[int] = prim::listconstruct(%2202: int, %2203: int)
# 	%2205: int = prim::constant[value = 1]()
# 	%2206: int = prim::constant[value = 1]()
# 	%2207: list[int] = prim::listconstruct(%2205: int, %2206: int)
# 	%2208: int = prim::constant[value = 1]()
# 	%2209: int = prim::constant[value = 1]()
# 	%2210: list[int] = prim::listconstruct(%2208: int, %2209: int)
# 	%2211: bool = prim::constant[value = 0]()
# 	%2212: int = prim::constant[value = 0]()
# 	%2213: int = prim::constant[value = 0]()
# 	%2214: list[int] = prim::listconstruct(%2212: int, %2213: int)
# 	%2215: int = prim::constant[value = 1]()
# 	%2216: bool = prim::constant[value = 0]()
# 	%2217: bool = prim::constant[value = 0]()
# 	%2218: bool = prim::constant[value = 1]()
# 	%input.138: float[1, 1024, 7, 7] = aten::_convolution(%input.137: float[1, 1024, 7, 7], %289: float[1024, 1024, 3, 3], %2201: none, %2204: list[int], %2207: list[int], %2210: list[int], %2211: bool, %2214: list[int], %2215: int, %2216: bool, %2217: bool, %2218: bool)
# 	%2220: bool = prim::constant[value = 0]()
# 	%2221: float = prim::constant[value = 0.1]()
# 	%2222: float = prim::constant[value = 1e-05]()
# 	%2223: bool = prim::constant[value = 1]()
# 	%input.139: float[1, 1024, 7, 7] = aten::batch_norm(%input.138: float[1, 1024, 7, 7], %290: float[1024], %291: float[1024], %292: float[1024], %293: float[1024], %2220: bool, %2221: float, %2222: float, %2223: bool)
# 	%input.140: float[1, 1024, 7, 7] = aten::relu_(%input.139: float[1, 1024, 7, 7])
# 	%2226: none = prim::constant()
# 	%2227: int = prim::constant[value = 1]()
# 	%2228: int = prim::constant[value = 1]()
# 	%2229: list[int] = prim::listconstruct(%2227: int, %2228: int)
# 	%2230: int = prim::constant[value = 0]()
# 	%2231: int = prim::constant[value = 0]()
# 	%2232: list[int] = prim::listconstruct(%2230: int, %2231: int)
# 	%2233: int = prim::constant[value = 1]()
# 	%2234: int = prim::constant[value = 1]()
# 	%2235: list[int] = prim::listconstruct(%2233: int, %2234: int)
# 	%2236: bool = prim::constant[value = 0]()
# 	%2237: int = prim::constant[value = 0]()
# 	%2238: int = prim::constant[value = 0]()
# 	%2239: list[int] = prim::listconstruct(%2237: int, %2238: int)
# 	%2240: int = prim::constant[value = 1]()
# 	%2241: bool = prim::constant[value = 0]()
# 	%2242: bool = prim::constant[value = 0]()
# 	%2243: bool = prim::constant[value = 1]()
# 	%input.141: float[1, 2048, 7, 7] = aten::_convolution(%input.140: float[1, 1024, 7, 7], %295: float[2048, 1024, 1, 1], %2226: none, %2229: list[int], %2232: list[int], %2235: list[int], %2236: bool, %2239: list[int], %2240: int, %2241: bool, %2242: bool, %2243: bool)
# 	%2245: bool = prim::constant[value = 0]()
# 	%2246: float = prim::constant[value = 0.1]()
# 	%2247: float = prim::constant[value = 1e-05]()
# 	%2248: bool = prim::constant[value = 1]()
# 	%2249: float[1, 2048, 7, 7] = aten::batch_norm(%input.141: float[1, 2048, 7, 7], %296: float[2048], %297: float[2048], %298: float[2048], %299: float[2048], %2245: bool, %2246: float, %2247: float, %2248: bool)
# 	%2250: int = prim::constant[value = 1]()
# 	%input.142: float[1, 2048, 7, 7] = aten::add_(%2249: float[1, 2048, 7, 7], %input.134: float[1, 2048, 7, 7], %2250: int)
# 	%input.143: float[1, 2048, 7, 7] = aten::relu_(%input.142: float[1, 2048, 7, 7])
# 	%2253: none = prim::constant()
# 	%2254: int = prim::constant[value = 1]()
# 	%2255: int = prim::constant[value = 1]()
# 	%2256: list[int] = prim::listconstruct(%2254: int, %2255: int)
# 	%2257: int = prim::constant[value = 0]()
# 	%2258: int = prim::constant[value = 0]()
# 	%2259: list[int] = prim::listconstruct(%2257: int, %2258: int)
# 	%2260: int = prim::constant[value = 1]()
# 	%2261: int = prim::constant[value = 1]()
# 	%2262: list[int] = prim::listconstruct(%2260: int, %2261: int)
# 	%2263: bool = prim::constant[value = 0]()
# 	%2264: int = prim::constant[value = 0]()
# 	%2265: int = prim::constant[value = 0]()
# 	%2266: list[int] = prim::listconstruct(%2264: int, %2265: int)
# 	%2267: int = prim::constant[value = 1]()
# 	%2268: bool = prim::constant[value = 0]()
# 	%2269: bool = prim::constant[value = 0]()
# 	%2270: bool = prim::constant[value = 1]()
# 	%input.144: float[1, 1024, 7, 7] = aten::_convolution(%input.143: float[1, 2048, 7, 7], %301: float[1024, 2048, 1, 1], %2253: none, %2256: list[int], %2259: list[int], %2262: list[int], %2263: bool, %2266: list[int], %2267: int, %2268: bool, %2269: bool, %2270: bool)
# 	%2272: bool = prim::constant[value = 0]()
# 	%2273: float = prim::constant[value = 0.1]()
# 	%2274: float = prim::constant[value = 1e-05]()
# 	%2275: bool = prim::constant[value = 1]()
# 	%input.145: float[1, 1024, 7, 7] = aten::batch_norm(%input.144: float[1, 1024, 7, 7], %302: float[1024], %303: float[1024], %304: float[1024], %305: float[1024], %2272: bool, %2273: float, %2274: float, %2275: bool)
# 	%input.146: float[1, 1024, 7, 7] = aten::relu_(%input.145: float[1, 1024, 7, 7])
# 	%2278: none = prim::constant()
# 	%2279: int = prim::constant[value = 1]()
# 	%2280: int = prim::constant[value = 1]()
# 	%2281: list[int] = prim::listconstruct(%2279: int, %2280: int)
# 	%2282: int = prim::constant[value = 1]()
# 	%2283: int = prim::constant[value = 1]()
# 	%2284: list[int] = prim::listconstruct(%2282: int, %2283: int)
# 	%2285: int = prim::constant[value = 1]()
# 	%2286: int = prim::constant[value = 1]()
# 	%2287: list[int] = prim::listconstruct(%2285: int, %2286: int)
# 	%2288: bool = prim::constant[value = 0]()
# 	%2289: int = prim::constant[value = 0]()
# 	%2290: int = prim::constant[value = 0]()
# 	%2291: list[int] = prim::listconstruct(%2289: int, %2290: int)
# 	%2292: int = prim::constant[value = 1]()
# 	%2293: bool = prim::constant[value = 0]()
# 	%2294: bool = prim::constant[value = 0]()
# 	%2295: bool = prim::constant[value = 1]()
# 	%input.147: float[1, 1024, 7, 7] = aten::_convolution(%input.146: float[1, 1024, 7, 7], %307: float[1024, 1024, 3, 3], %2278: none, %2281: list[int], %2284: list[int], %2287: list[int], %2288: bool, %2291: list[int], %2292: int, %2293: bool, %2294: bool, %2295: bool)
# 	%2297: bool = prim::constant[value = 0]()
# 	%2298: float = prim::constant[value = 0.1]()
# 	%2299: float = prim::constant[value = 1e-05]()
# 	%2300: bool = prim::constant[value = 1]()
# 	%input.148: float[1, 1024, 7, 7] = aten::batch_norm(%input.147: float[1, 1024, 7, 7], %308: float[1024], %309: float[1024], %310: float[1024], %311: float[1024], %2297: bool, %2298: float, %2299: float, %2300: bool)
# 	%input.149: float[1, 1024, 7, 7] = aten::relu_(%input.148: float[1, 1024, 7, 7])
# 	%2303: none = prim::constant()
# 	%2304: int = prim::constant[value = 1]()
# 	%2305: int = prim::constant[value = 1]()
# 	%2306: list[int] = prim::listconstruct(%2304: int, %2305: int)
# 	%2307: int = prim::constant[value = 0]()
# 	%2308: int = prim::constant[value = 0]()
# 	%2309: list[int] = prim::listconstruct(%2307: int, %2308: int)
# 	%2310: int = prim::constant[value = 1]()
# 	%2311: int = prim::constant[value = 1]()
# 	%2312: list[int] = prim::listconstruct(%2310: int, %2311: int)
# 	%2313: bool = prim::constant[value = 0]()
# 	%2314: int = prim::constant[value = 0]()
# 	%2315: int = prim::constant[value = 0]()
# 	%2316: list[int] = prim::listconstruct(%2314: int, %2315: int)
# 	%2317: int = prim::constant[value = 1]()
# 	%2318: bool = prim::constant[value = 0]()
# 	%2319: bool = prim::constant[value = 0]()
# 	%2320: bool = prim::constant[value = 1]()
# 	%input.150: float[1, 2048, 7, 7] = aten::_convolution(%input.149: float[1, 1024, 7, 7], %313: float[2048, 1024, 1, 1], %2303: none, %2306: list[int], %2309: list[int], %2312: list[int], %2313: bool, %2316: list[int], %2317: int, %2318: bool, %2319: bool, %2320: bool)
# 	%2322: bool = prim::constant[value = 0]()
# 	%2323: float = prim::constant[value = 0.1]()
# 	%2324: float = prim::constant[value = 1e-05]()
# 	%2325: bool = prim::constant[value = 1]()
# 	%2326: float[1, 2048, 7, 7] = aten::batch_norm(%input.150: float[1, 2048, 7, 7], %314: float[2048], %315: float[2048], %316: float[2048], %317: float[2048], %2322: bool, %2323: float, %2324: float, %2325: bool)
# 	%2327: int = prim::constant[value = 1]()
# 	%input.151: float[1, 2048, 7, 7] = aten::add_(%2326: float[1, 2048, 7, 7], %input.143: float[1, 2048, 7, 7], %2327: int)
# 	%input.152: float[1, 2048, 7, 7] = aten::relu_(%input.151: float[1, 2048, 7, 7])
# 	%2342: int = prim::constant[value = 1]()
# 	%2343: int = prim::constant[value = 1]()
# 	%2344: list[int] = prim::listconstruct(%2342: int, %2343: int)
# 	%2345: float[1, 2048, 1, 1] = aten::adaptive_avg_pool2d(%input.152: float[1, 2048, 7, 7], %2344: list[int])
# 	%2346: int = prim::constant[value = 1]()
# 	%2347: int = prim::constant[value = -1]()
# 	%input: float[1, 2048] = aten::flatten(%2345: float[1, 2048, 1, 1], %2346: int, %2347: int)
# 	%2349: float[2048, 1000] = aten::t(%319: float[1000, 2048])
# 	%2350: int = prim::constant[value = 1]()
# 	%2351: int = prim::constant[value = 1]()
# 	%2352: float[1, 1000] = aten::addmm(%320: float[1000], %input: float[1, 2048], %2349: float[2048, 1000], %2350: int, %2351: int)
# 	return %2352: float[1, 1000]
# wide_resnet50_2: 11.4 G
# wide_resnet101_2: 22.75 G
# vgg11: 7.609 G
# vgg11_bn: 7.609 G
# vgg13: 11.31 G
# vgg13_bn: 11.31 G
# vgg16: 15.47 G
# vgg16_bn: 15.47 G
# vgg19_bn: 19.63 G
# vgg19: 19.63 G
# squeezenet1_0: 0.8189 G
# squeezenet1_1: 0.3492 G
# inception_v3: 5.715 G
# densenet121: 2.834 G
# densenet169: 3.36 G
# densenet201: 4.292 G
# densenet161: 7.728 G
# googlenet: 1.498 G
# /home/khushal/anaconda2/envs/dl/lib/python3.6/site-packages/torchprofile/profile.py:23: UserWarning: No handlers found: "aten::reshape". Skipped.
#   node.operator))
# mobilenet_v2: 0.3008 G
# mnasnet0_5: 0.1045 G
# mnasnet0_75: 0.2155 G
# mnasnet1_0: 0.3144 G
# mnasnet1_3: 0.5264 G
# /home/khushal/anaconda2/envs/dl/lib/python3.6/site-packages/torchprofile/profile.py:23: UserWarning: No handlers found: "aten::floor_divide". Skipped.
#   node.operator))
# shufflenet_v2_x0_5: 0.04048 G
# /home/khushal/anaconda2/envs/dl/lib/python3.6/site-packages/torchprofile/profile.py:23: UserWarning: No handlers found: "aten::floor_divide". Skipped.
#   node.operator))
# shufflenet_v2_x1_0: 0.1449 G
# /home/khushal/anaconda2/envs/dl/lib/python3.6/site-packages/torchprofile/profile.py:23: UserWarning: No handlers found: "aten::floor_divide". Skipped.
#   node.operator))
# shufflenet_v2_x1_5: 0.2958 G
# shufflenet_v2_x2_0: 0.5833 G
# /home/khushal/anaconda2/envs/dl/lib/python3.6/site-packages/torchprofile/profile.py:23: UserWarning: No handlers found: "aten::floor_divide". Skipped.
#   node.operator))

# %%
# import torch
# import torch.nn as nn
# from torch.nn.modules.transformer import Transformer
# from torchprofile.utils.trace import trace

# from torchprofile import profile_macs

# if __name__ == '__main__':
#     embed_size = 512
#     num_tokens = 30
#     model = nn.MultiheadAttention(embed_dim=embed_size*30, num_heads=num_tokens)
#     # model = Transformer(embed_size)
#     inputs = (
#         torch.randn(num_tokens, 1, embed_size),
#         torch.randn(num_tokens, 1, embed_size),
#     )

#     macs = profile_macs(model, inputs)
#     graph = trace(model,inputs)
#     print('transformer: {:.4g} G'.format(macs / 1e9))
#     print(graph)
